# %% [markdown]
# ### Assignment
#
# Write solution for the below tasks in the given space & write the same in A4 sheets as well.

# %% [markdown]
# 1. What is Python? Explain 4 advantages & 2 disadvantages. Mention 2 differences between Python2 & Python3.

# %% [markdown]
# 2. Write a Python program to
#    1. take an input,
#    2. square it,
#    3. convert it to String, &
#    4. reverse the String.

# %%
a = 34
print(f'Square of {a} is {a**2}')
print(f'{a} Converted to string result is {str(a)}')

# %% [markdown]
# 3. Write a Python User-defined function to return "Distinction" if the result is more than 75%, "First Class" if the result is more than 60%, "Pass" if the result is more than 40%, "Fail" otherwise.
#
# Consider total marks to be 500 and calculate percentage beforehand.

# %% [markdown]
# 4. Write different functions to
#    1. create a list of 10 numbers, *num*
#    2. convert the list *num* into dictionary mapping the numbers to their squares, &
#    3. print a new list of odd numbers from *num*.

# %% [markdown]
# 5. Write a program to
#    1. create a file named data.txt,
#    2. write 5 lines into it,
#    3. read the content and print it,
#    4. count the number of words in the file.

# %% [markdown]
# 6. Write a program to
#    1. create a DataFrame with *name, department, salary*,
#    2. group employees by *department*,
#    3. calculate average salary, total salary.

# %% [markdown]
# 7. Two DataFrames are given, employees.csv, salary.csv
#
# Write Python functions to
# 1. merge them using ID,
# 2. create a column using apply() that categorizes salary as
#    1. 'High' if > 50,000
#    2. 'Low' otherwise

# %% [markdown]
# 8. Given the string
#
# "Contact us at support@abc.com or hr@xyz.org"
#
# Write regex code to
# 1. extract all email addresses,
# 2. extract only domain names.

# %% [markdown]
# 9. Write a Python program that
#    1.  stores 2 numbers,
#    2.  divides them,
#    3.  handling the following error using try/except
#        1.  division by zero,
#        2.  invalid input,
#        3.  unknown error.

# %% [markdown]
# 10. Explain
#     1.  why Regression Analysis is used,
#     2.  write Python code to:
#         1.  load a CSV file using Pandas.
#         2.  perform
#             1.  .info()
#             2.  .describe()
#             3.  check missing values
